# %% [markdown]
# # Exploring SQL capabilities
#
# Dev: Jeison Robles

# %% [markdown]
# ## Simple SQL query

# %%
# %sql


SELECT * FROM delta_demo_table

# %% [markdown]
# ## Exploring Table History  (Delta Lake Feature)

# %%
# %sql
DESCRIBE HISTORY delta_demo_table

# %% [markdown]
# ## Time Travel on SQL

# %%
# %sql
SELECT 
* 
FROM delta_demo_table 
VERSION AS OF 0 --THIS IS A PURE DELTA CAPABILITY

# %% [markdown]
# ## Explore meta deta

# %%
# %sql
DESCRIBE DETAIL delta_demo_table
